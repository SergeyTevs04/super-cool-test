# %%
import pandas as pd

# %%
df = pd.read_csv('ads.csv', index_col=['date', 'ad_channel', 'country'])
df.head(37)
# Out:
#                                impressions  clicks  ad_spend
# date       ad_channel country
# 2026-01-01 Google     RU             12500     245    156.25
#            Facebook   UA              9800     156     98.00
#            Yandex     KZ             15400     308    192.50
#            Instagram  US              7200     108     72.00
#            Google     RU             11200     224    140.00
# 2026-01-02 Facebook   UA             10350     165    103.50
#            Yandex     KZ             16700     334    208.75
#            Instagram  US              6850     103     68.50
#            Google     RU             11900     238    148.75
#            TikTok     CN              4500      90     45.00
# 2026-01-03 Google     RU             13400     268    167.50
#            Facebook   UA              9200     138     92.00
#            Yandex     KZ             14250     285    178.13
#            Instagram  US              7800     117     78.00
#            Google     RU             10800     216    135.00
# 2026-01-04 Facebook   UA             11500     184    115.00
#            Yandex     KZ             16100     322    201.25
#            Instagram  US              7100     106     71.00
#            TikTok     CN              5200     104     52.00
#            Google     RU             12750     255    159.38
# 2026-01-05 Yandex     KZ             14800     296    185.00
#            Facebook   UA              9500     152     95.00
#            Google     RU             13200     264    165.00
#            Instagram  US              7400     111     74.00
#            TikTok     CN              4800      96     48.00
# 2026-01-06 Google     RU             14100     282    176.25
#            Yandex     KZ             15500     310    193.75
#            Facebook   UA              9850     157     98.50
#            Instagram  US              6950     104     69.50
# 2026-01-07 Google     RU             12300     246    153.75
#            TikTok     CN              5100     102     51.00
#            Yandex     KZ             16900     338    211.25
#            Facebook   UA             10700     171    107.00
#            Instagram  US              7650     115     76.50
# 2026-01-08 Google     RU             13600     272    170.00
#            Yandex     KZ             15200     304    190.00
#            Facebook   UA             11200     179    112.00

# %%
# df.loc['2026-01-01'].loc['Google'] # Подмножество строк и обращаемся дальше к ним как в составных данных

# %%
# Агрегирование серий
# df.dtypes # Смотрим типы данных в дф
# df['ad_spend'].sum() # Сумма серии 
# df['ad_spend'].count() # Подсчет количества элементов серии
# df['ad_spend'].min()
# df['ad_spend'].max()
# df['ad_spend'].mean() # Среднее арифметическое 
# df['ad_spend'].std() # Стандартное отклонение 
# df['ad_spend'].median()
# df['ad_spend'].quantile() 
# df['ad_spend'].unique() # Массив уникальных значений 
# df['ad_spend'].nunique() # Считает количество уникальных значений 
# df['ad_spend'].idxmax() # Находит индекс максимального значения

# %%
# Агрегирование датафреймов 
# df.sum() # Пойдет по каждой колонке, и если там можно применить sum, то применит 
# df.sum()['impressions'] # Здесь суммирует определенную колонку
# df.sum(axis='columns') # Сумму можно применять как построчно, так и по колонкам. По оси!
# Out:
# date        ad_channel  country
# 2026-01-01  Google      RU         12901.25
#             Facebook    UA         10054.00
#             Yandex      KZ         15900.50
#             Instagram   US          7380.00
#             Google      RU         11564.00
#                                      ...
# 2026-01-31  Google      RU         14300.13
#             TikTok      CN          4686.50
#             Yandex      KZ         16674.88
#             Facebook    UA         11286.00
#             Instagram   US          7585.00
# Length: 146, dtype: float64
