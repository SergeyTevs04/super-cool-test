# %%
import pandas as pd

# %%
# Два типа конкатенации 1 - вертикальный(ставим один дф на другой сверху) 2 - горизонтальный(схлопываем датафреймы сбоку)

# %%
# germany = pd.read_csv('practice/sales_germany.csv')
# germany.head()

# %%
# france = pd.read_csv('practice/sales_france.csv')
# france.head()

# %%
# df = pd.concat([france, germany], axis='rows') # axis='rows' - Значит идем вдоль строк(Первая строка, вторая строка и тд). Идем вертикально!

# %%
# goods = pd.read_csv('practice/goods.csv')
# goods.head()

# %%
# ratings = pd.read_csv('practice/ratings.csv')
# ratings.head()

# %%
# pd.concat([goods, ratings], axis='columns') # Идем горизонтально! По колонкам! 
# Удобно, если нам в датафрейм нужно добавить несколько колонок - Мы сначала создаем список с нужными колонками, а потом слепливаем их с нужным дф!
