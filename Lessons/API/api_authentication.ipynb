# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Auth # 1 способ - api_key в url

func = 'TIME_SERIES_DAILY'
symbol = 'TSLA'
api_key = os.getenv('api_key')

url = f'https://www.alphavantage.co/query?function={func}&symbol={symbol}&interval=5min&apikey={api_key}'

r = requests.get(url)

data = r.json()

data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'TSLA',
#   '3. Last Refreshed': '2026-04-07',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2026-04-07': {'1. open': '346.4400',
#    '2. high': '348.0200',
#    '3. low': '337.2400',
#    '4. close': '346.6500',
#    '5. volume': '74515355'},
#   '2026-04-06': {'1. open': '362.5900',
#    '2. high': '367.7200',
#    '3. low': '346.6400',
#    '4. close': '352.8200',
#    '5. volume': '77697643'},
#   '2026-04-02': {'1. open': '364.1950',
#    '2. high': '370.2800',
#    '3. low': '359.0300',
#    '4. close': '360.5900',
#    '5. volume': '83031226'},
#   '2026-04-01': {'1. open': '378.6300',
#    '2. high': '383.1400',
#    '3. low': '374.0800',
#    '4. close': '381.2600',
#    '5. volume': '58683752'},
#   '2026-03-31': {'1. open': '361.5100',
#    '2. high': '373.3300',
#    '3. low': '361.0000',
#    '4. close': '371.7500',
# ...

# %%
# Auth #2 способ - api_key в url

# headers = {
#     'Authorization': 'Bearer YOUR_TOKEN',
# }

# response = requests.get('https://api.airtable.com/v0/YOUR_BASE_ID/YOUR_TABLE_ID_OR_NAME', headers=headers)

# %%
# import os
# Переменные окружения # 1 способ
# dict(os.environ)['ITERM_PROFILE']
# os.getenv('ITERM_PROFILE')

# %%
# os.environ['FOO'] = "1"
# os.getenv('FOO')
# Out:
# '1'

# %%
# 2 способ
# Out:
# True

# %%
# os.getenv('api_key')
# Out:
# '2MG6PG42651NNEOC'
