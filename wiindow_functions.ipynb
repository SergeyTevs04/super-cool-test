# %%
import pandas as pd

# %%
df = pd.read_csv('daily_visitors_dynamic.csv')
df.head()
# Out:
#          date   ad_channel  daily_visitors
# 0  2026-01-01       google              52
# 1  2026-01-01     facebook              50
# 2  2026-01-01      youtube              55
# 3  2026-01-01    instagram              53
# 4  2026-01-01  influencers              51

# %%
df.groupby('date').sum()
# Out:
#                                            ad_channel  daily_visitors
# date
# 2026-01-01  googlefacebookyoutubeinstagraminfluencers             261
# 2026-01-02  googlefacebookyoutubeinstagraminfluencers             271
# 2026-01-03  googlefacebookyoutubeinstagraminfluencers             280
# 2026-01-04  googlefacebookyoutubeinstagraminfluencers             290
# 2026-01-05  googlefacebookyoutubeinstagraminfluencers             300
# 2026-01-06  googleyoutubefacebookinstagraminfluencers             310
# 2026-01-07  googlefacebookyoutubeinstagraminfluencers             320
# 2026-01-08  instagramgooglefacebookyoutubeinfluencers             330
# 2026-01-09  googleyoutubefacebookinstagraminfluencers             340
# 2026-01-10  googlefacebookinstagramyoutubeinfluencers             350
# 2026-01-11  googleyoutubefacebookinstagraminfluencers             360
# 2026-01-12  googleinstagramfacebookyoutubeinfluencers             370
# ...
